# %%
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
names = ['Beach', 'Forest', 'Highway', 'Mountain', 'Office']

# %%
mt1 = np.array([0.1648337691, 0.0030183939, 0.0224736057, 0.0013149385, 0.0004571484])
mt2 = np.array([0.0002204666, 0.1316437673, 0.0034628806, 0.0012086847, 0.0002229967])
mt3 = np.array([0.0003348257, 0.0051098627, 0.5812112501, 0.0007208646, 0.0026685175])
mt4 = np.array([0.0050448964, 0.0021397665, 0.0071412618, 0.228976132, 0.000847216])
mt5 = np.array([2.43958e-05, 1.79514e-05, 5.26967e-05, 2.51596e-05, 0.3276337635])
mt6 = np.array([0.1298479935, 0.0016443247, 0.010589976, 0.0029662222, 0.0011828299])
mt7 = np.array([0.000421196, 0.1282767997, 0.0080306139, 0.0058093393, 0.0003201966])
mt8 = np.array([0.0013091866, 0.0138897519, 0.3905307212, 0.0022117822, 0.0101355618])
mt9 = np.array([0.010983068, 0.0071614556, 0.0148258127, 0.1103476975, 0.0012841328])
mt10 = np.array([3.30235e-05, 2.42375e-05, 2.09103e-05, 1.71913e-05, 0.3383593712])
mt11 = np.array([0.0540899866, 0.004434822, 0.0096232303, 0.0072854877, 0.0027180381])
mt12 = np.array([0.0006006054, 0.0113750085, 0.0087300146, 0.000603447, 0.0007170855])
mt13 = np.array([0.0015005111, 0.003788742, 0.1197696868, 0.0017519177, 0.0120163979])
mt14 = np.array([0.0184503274, 0.014828013, 0.014253485, 0.0317248575, 0.000316773])
mt15 = np.array([6.36506e-05, 0.0005278924, 0.0002995139, 2.74086e-05, 0.1122879077])

# %%
matrix1 = [mt1/sum(mt1),mt2/sum(mt2),mt3/sum(mt3),mt4/sum(mt4),mt5/sum(mt5)]
matrix2 = [mt6/sum(mt6),mt7/sum(mt7),mt8/sum(mt8),mt9/sum(mt9),mt10/sum(mt10)]
matrix3 = [mt11/sum(mt11),mt12/sum(mt12),mt13/sum(mt13),mt14/sum(mt14),mt15/sum(mt15)]

# %%
df_cm = pd.DataFrame(matrix1, index = [i for i in names], columns = [i for i in names])
plt.figure(figsize = (15,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("goodbad_matrix_googlenet_ST_good.png")
df_cm = pd.DataFrame(matrix2, index = [i for i in names], columns = [i for i in names])
plt.figure(figsize = (15,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("goodbad_matrix_googlenet_ST_medium.png")
df_cm = pd.DataFrame(matrix3, index = [i for i in names], columns = [i for i in names])
plt.figure(figsize = (15,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("goodbad_matrix_googlenet_ST_bad.png")
