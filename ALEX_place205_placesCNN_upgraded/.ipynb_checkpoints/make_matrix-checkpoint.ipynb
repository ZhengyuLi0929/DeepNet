# %%
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
names = ['Beach', 'Forest', 'Highway', 'Mountain', 'Office']

# %%
mt1 = np.array([0.1214500164, 0.0013600451, 0.008052167, 0.00218269, 0.0010919062])
mt2 = np.array([0.0002031822, 0.0901307971, 0.0007564469, 0.0006069001, 0.0005262979])
mt3 = np.array([0.0010935279, 0.0066003451, 0.288847505, 0.0007307338, 0.0043188045])
mt4 = np.array([0.013730361, 0.0023328387, 0.005790886, 0.1329468178, 0.003252853])
mt5 = np.array([6.81354e-05, 9.1172e-06, 0.0002501747, 1.41299e-05, 0.1898327323])
mt6 = np.array([0.0745701644, 0.002181364, 0.0089490028, 0.0028756243, 0.0019161017])
mt7 = np.array([0.000664036, 0.0606563725, 0.0013837438, 0.0039656277, 0.0004447172])
mt8 = np.array([0.0020815703, 0.0080829363, 0.2048632183, 0.0013048908, 0.0072140701])
mt9 = np.array([0.0093811484, 0.006661197, 0.0068335331, 0.0694139612, 0.0048489432])
mt10 = np.array([0.0008400942, 1.38118e-05, 0.000236044, 1.67535e-05, 0.2274015865])
mt11 = np.array([0.0411886135, 0.0023407547, 0.0035164386, 0.0049941981, 0.0039399142])
mt12 = np.array([0.0006835588, 0.0069086632, 0.0034967311, 0.0007298613, 0.0012605331])
mt13 = np.array([0.0021092434, 0.0015054939, 0.0430821053, 0.000647931, 0.0127376727])
mt14 = np.array([0.0125058312, 0.0046152658, 0.010515719, 0.0223799481, 0.0011140916])
mt15 = np.array([0.0001264565, 0.0002713454, 0.0003028441, 2.76934e-05, 0.1045448859])

# %%
matrix1 = [mt1/sum(mt1),mt2/sum(mt2),mt3/sum(mt3),mt4/sum(mt4),mt5/sum(mt5)]
matrix2 = [mt6/sum(mt6),mt7/sum(mt7),mt8/sum(mt8),mt9/sum(mt9),mt10/sum(mt10)]
matrix3 = [mt11/sum(mt11),mt12/sum(mt12),mt13/sum(mt13),mt14/sum(mt14),mt15/sum(mt15)]

# %%
df_cm = pd.DataFrame(matrix1, index = [i for i in names], columns = [i for i in names])
plt.figure(figsize = (15,7))
fig = sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("goodbad_matrix_Alex_ST_good.png")
df_cm = pd.DataFrame(matrix2, index = [i for i in names], columns = [i for i in names])
plt.figure(figsize = (15,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("goodbad_matrix_Alex_ST_medium.png")
df_cm = pd.DataFrame(matrix3, index = [i for i in names], columns = [i for i in names])
plt.figure(figsize = (15,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("goodbad_matrix_Alex_ST_bad.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-952ac5993960> in <module>
#       2 plt.figure(figsize = (15,7))
#       3 fig = sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
# ----> 4 fig['layout'].update(plot_bgcolor='red')
#       5 plt.savefig("goodbad_matrix_Alex_ST_good.png")
#       6 df_cm = pd.DataFrame(matrix2, index = [i for i in names], columns = [i for i in names])
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
a = "41637201743422336021899948422346634385819988194716785024331073815534226305167"
b = "27182823072334415400340619747360022126040373783683343960064540014469195618458"

# %%
len(a)
# Out:
# 77
