# %%
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
names = ['Bedroom', 'Dining', 'Forest', 'Hospital', 'Mountain', 'Office']

# %%
mt1 = [0.0577769997, 3.54898e-05, 2.83e-08, 0.0014804654, 3.07e-07, 0.0005327469]
mt2 = [2.8768e-06, 0.0006482014, 7.41e-08, 9.0803e-06, 1.0547e-06, 0.000128259]
mt3 = [7e-08, 2.445e-07, 0.3470846768, 2.978e-07, 2.56536e-05, 3.425e-07]
mt4 = [0.0001488816, 5.44683e-05, 1.649e-07, 0.3075043187, 1.2207e-06, 0.0001952693]
mt5 = [4.998e-07, 3.507e-07, 0.0046060997, 8.652e-07, 0.0267266448, 1.069e-06]
mt6 = [6.07187e-05, 0.0022882838, 3.749e-07, 0.0011982263, 1.8153e-06, 0.1411490208]

# %%
matrix = [mt1,mt2,mt3,mt4,mt5,mt6]

# %%
df_cm = pd.DataFrame(matrix)
plt.figure(figsize = (15,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("conf_matrix.jpg")
