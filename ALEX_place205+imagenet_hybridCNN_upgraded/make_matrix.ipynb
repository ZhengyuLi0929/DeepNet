# %%
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
names = ['Beach', 'Forest', 'Highway', 'Mountain', 'Office']

# %%
mt1 = np.array([3.25647e-05, 0.0002190723, 3.28413e-05, 6.5976e-05, 2.92678e-05])
mt2 = np.array([9.94714e-05, 0.0001846871, 2.76825e-05, 1.76389e-05, 0.0001299653])
mt3 = np.array([1.94258e-05, 5.19589e-05, 1.94772e-05, 6.1617e-06, 1.44039e-05])
mt4 = np.array([4.64882e-05, 0.0002593742, 2.59956e-05, 0.000567126, 7.15772e-05])
mt5 = np.array([1.6501e-06, 1.46354e-05, 3.0945e-06, 1.82029e-05, 2.91472e-05])
mt6 = np.array([0.0001006478, 0.0003195115, 8.13882e-05, 0.000246174, 0.000103812])
mt7 = np.array([0.0001002112, 0.0003844899, 3.52956e-05, 3.77376e-05, 0.0003145084])
mt8 = np.array([7.1053e-06, 5.54503e-05, 1.19034e-05, 9.0913e-06, 1.06102e-05])
mt9 = np.array([4.33851e-05, 0.0002337268, 3.25138e-05, 0.0005694095, 6.50231e-05])
mt10 = np.array([1.8012e-06, 1.07553e-05, 2.4733e-06, 2.46951e-05, 2.94524e-05])
mt11 = np.array([3.39124e-05, 0.0007590246, 5.02835e-05, 0.000150505, 0.0001054593])
mt12 = np.array([3.7826e-05, 0.0001221071, 1.98586e-05, 1.83986e-05, 0.0001877162])
mt13 = np.array([2.28059e-05, 7.54967e-05, 3.25769e-05, 2.22496e-05, 7.22609e-05])
mt14 = np.array([8.34426e-05, 0.0003382924, 4.4377e-05, 0.0002903445, 8.89441e-05])
mt15 = np.array([3.9717e-06, 3.72876e-05, 7.2885e-06, 4.79253e-05, 2.99833e-05])

# %%
matrix1 = [mt1/sum(mt1),mt2/sum(mt2),mt3/sum(mt3),mt4/sum(mt4),mt5/sum(mt5)]
matrix2 = [mt6/sum(mt6),mt7/sum(mt7),mt8/sum(mt8),mt9/sum(mt9),mt10/sum(mt10)]
matrix3 = [mt11/sum(mt11),mt12/sum(mt12),mt13/sum(mt13),mt14/sum(mt14),mt15/sum(mt15)]

# %%
df_cm = pd.DataFrame(matrix1, index = [i for i in names], columns = [i for i in names])
plt.figure(figsize = (15,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("goodbad_matrix_alexHybrid_ST_good.png")
df_cm = pd.DataFrame(matrix2, index = [i for i in names], columns = [i for i in names])
plt.figure(figsize = (15,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("goodbad_matrix_alexHybrid_ST_medium.png")
df_cm = pd.DataFrame(matrix3, index = [i for i in names], columns = [i for i in names])
plt.figure(figsize = (15,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.savefig("goodbad_matrix_alexHybrid_ST_bad.png")

# %%
print("as"+str(mt1)+")")
# Out:
# as[4.645316e-04 2.524700e-06 2.808420e-05 3.158000e-05 2.163700e-06])
